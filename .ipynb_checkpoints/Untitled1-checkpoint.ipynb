# %%
import suite2p
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob
from natsort import natsorted
from multiprocessing import Pool

# %%
opsSetfile=r'C:\Users\User\Project-SLMonline\ops3Planes.npy';
ops0 = np.load(opsSetfile,allow_pickle=True).item()
ops0['input_format']='binary';
#ops0['save_path0']='C:/Users/zhangl33/Projects/Project4-SLMonline/LuSLMOnlineTest/02082024/'
ops0['save_path0']=r'F:\LuSLMOnlineTest\02282024\\'
ops0['Lx']=512  ##Width of a image
ops0['Ly']=512  ##Height of a image
ops0['xrange']=[0,512]
ops0['yrange']=[0,512]
ops0['nplanes']=3
ops0['nchannels']=1
ops0['tau']=0.9
ops0['fs']=6.9;
nplanes=ops0['nplanes'];
binFile = glob.glob(ops0['save_path0'] + '/*039Laser1.2Point1.bin')
#binFile = glob.glob(ops0['save_path0'] + '/*027.bin')
print(binFile[0])

rawBin = suite2p.io.BinaryFile(Ly=ops0['Ly'],Lx=ops0['Lx'], filename=binFile[0])
nFrame = rawBin.shape[0] // nplanes
print(rawBin.shape[0])
print(nFrame)
#del statExample
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 17
#      15 binFile = glob.glob(ops0['save_path0'] + '/*039Laser1.2Point1.bin')
#      16 #binFile = glob.glob(ops0['save_path0'] + '/*027.bin')
# ---> 17 print(binFile[0])
#      19 rawBin = suite2p.io.BinaryFile(Ly=ops0['Ly'],Lx=ops0['Lx'], filename=binFile[0])
#      20 nFrame = rawBin.shape[0] // nplanes
#
# IndexError: list index out of range
